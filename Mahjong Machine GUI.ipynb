# %% [markdown]
# This project took around 1500 lines of code

# %%
# import packages and display preferences
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import tkinter as tk


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None) 
pd.set_option('display.max_colwidth', -1)

# get card (df_full), functions, and deck
# %run ./2020_Card.ipynb
# %run ./Functions.ipynb
# Out:
# /Users/mneedle/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %% [markdown]
# # Reload alive minus hand if program crashes

# %%
alive = ''
with open('alive_minus_hand.txt','r') as f:
         for i in f.readlines():
            alive=i #string
alive = eval(alive) # this is orignal dict with instace dict

# %% [markdown]
# # Start game with full deck and empty hand

# %%
your_hand = []
alive = Counter(create_deck())

# %% [markdown]
# # Continue game with your_hand and deck

# %%
# LAUNCH GUI

# get card (df_full), functions, and deck
# %run ./Card.ipynb
# %run ./Functions.ipynb

# GUI
root = tk.Tk()
frame = tk.Frame(root)
frame.pack(fill=tk.Y, side=tk.LEFT, expand=True)

# your_hand
your_hand_label = tk.Label(frame, text="YOUR HAND   Tile Count: ")
your_hand_label.grid(row=1, column = 4, columnspan = 2, sticky= 'e')
tile_count_text = str(len(your_hand))
tile_count_2 = tk.Label(frame, text = tile_count_text)
tile_count_2.grid(row = 1, column = 6)
clear_hand = tk.Button(frame, text="CLEAR HAND",command=clear_hand)
clear_hand.grid(row=1,column=10)
your_hand_displayed_text = str(dict(Counter(your_hand)))
your_hand_displayed = tk.Label(frame, text = your_hand_displayed_text)
your_hand_displayed.grid(row = 2, column = 1, columnspan = 10)

# skip space 1
skip_space_1 = tk.Label(frame, text=" ")
skip_space_1.grid(row=3, column = 1, columnspan = 10)

# add tiles
add_tiles = tk.Label(frame, text="Add Tiles to Your Hand")
add_tiles.grid(row=4,column=1, columnspan = 10)
# bam
bam0 = tk.Button(frame, text="GREEN",command=bam0)
bam0.grid(row=5,column=1)
bam1 = tk.Button(frame, text="(1,'Bam')",command=bam1)
bam1.grid(row=5,column=2)
bam2 = tk.Button(frame, text="(2,'Bam')",command=bam2)
bam2.grid(row=5,column=3)
bam3 = tk.Button(frame, text="(3,'Bam')",command=bam3)
bam3.grid(row=5,column=4)
bam4 = tk.Button(frame, text="(4,'Bam')",command=bam4)
bam4.grid(row=5,column=5)
bam5 = tk.Button(frame, text="(5,'Bam')",command=bam5)
bam5.grid(row=5,column=6)
bam6 = tk.Button(frame, text="(6,'Bam')",command=bam6)
bam6.grid(row=5,column=7)
bam7 = tk.Button(frame, text="(7,'Bam')",command=bam7)
bam7.grid(row=5,column=8)
bam8 = tk.Button(frame, text="(8,'Bam')",command=bam8)
bam8.grid(row=5,column=9)
bam9 = tk.Button(frame, text="(9,'Bam')",command=bam9)
bam9.grid(row=5,column=10)
# crack
crack0 = tk.Button(frame, text="RED",command=crack0)
crack0.grid(row=6,column=1)
crack1 = tk.Button(frame, text="(1,'Crack')",command=crack1)
crack1.grid(row=6,column=2)
crack2 = tk.Button(frame, text="(2,'Crack')",command=crack2)
crack2.grid(row=6,column=3)
crack3 = tk.Button(frame, text="(3,'Crack')",command=crack3)
crack3.grid(row=6,column=4)
crack4 = tk.Button(frame, text="(4,'Crack')",command=crack4)
crack4.grid(row=6,column=5)
crack5 = tk.Button(frame, text="(5,'Crack')",command=crack5)
crack5.grid(row=6,column=6)
crack6 = tk.Button(frame, text="(6,'Crack')",command=crack6)
crack6.grid(row=6,column=7)
crack7 = tk.Button(frame, text="(7,'Crack')",command=crack7)
crack7.grid(row=6,column=8)
crack8 = tk.Button(frame, text="(8,'Crack')",command=crack8)
crack8.grid(row=6,column=9)
crack9 = tk.Button(frame, text="(9,'Crack')",command=crack9)
crack9.grid(row=6,column=10)
# dot
dot0 = tk.Button(frame, text="SOAP",command=dot0)
dot0.grid(row=7,column=1)
dot1 = tk.Button(frame, text="(1,'Dot')",command=dot1)
dot1.grid(row=7,column=2)
dot2 = tk.Button(frame, text="(2,'Dot')",command=dot2)
dot2.grid(row=7,column=3)
dot3 = tk.Button(frame, text="(3,'Dot')",command=dot3)
dot3.grid(row=7,column=4)
dot4 = tk.Button(frame, text="(4,'Dot')",command=dot4)
dot4.grid(row=7,column=5)
dot5 = tk.Button(frame, text="(5,'Dot')",command=dot5)
dot5.grid(row=7,column=6)
dot6 = tk.Button(frame, text="(6,'Dot')",command=dot6)
dot6.grid(row=7,column=7)
dot7 = tk.Button(frame, text="(7,'Dot')",command=dot7)
dot7.grid(row=7,column=8)
dot8 = tk.Button(frame, text="(8,'Dot')",command=dot8)
dot8.grid(row=7,column=9)
dot9 = tk.Button(frame, text="(9,'Dot')",command=dot9)
dot9.grid(row=7,column=10)
# winds, joker, and flower
north = tk.Button(frame, text="(North,'x')",command=north)
north.grid(row=8,column=1)
east = tk.Button(frame, text="('East','x')",command=east)
east.grid(row=8,column=2)
west = tk.Button(frame, text="('West','x')",command=west)
west.grid(row=8,column=3)
south = tk.Button(frame, text="('South','x')",command=south)
south.grid(row=8,column=4)
joker = tk.Button(frame, text="('Joker','x')",command=joker)
joker.grid(row=8,column=5)
flower = tk.Button(frame, text="('Flower','x')",command=flower)
flower.grid(row=8,column=6)

# skip space 2
skip_space_2 = tk.Label(frame, text="")
skip_space_2.grid(row=9, column = 1, columnspan = 10)

# remove tiles from your hard
discard_tiles_2 = tk.Label(frame, text="Remove Tiles from YOUR HAND")
discard_tiles_2.grid(row=10, column = 1, columnspan = 10)
# bam
ba0 = tk.Button(frame, text="GREEN",command=ba0)
ba0.grid(row=11,column=1)
ba1 = tk.Button(frame, text="(1,'Bam')",command=ba1)
ba1.grid(row=11,column=2)
ba2 = tk.Button(frame, text="(2,'Bam')",command=ba2)
ba2.grid(row=11,column=3)
ba3 = tk.Button(frame, text="(3,'Bam')",command=ba3)
ba3.grid(row=11,column=4)
ba4 = tk.Button(frame, text="(4,'Bam')",command=ba4)
ba4.grid(row=11,column=5)
ba5 = tk.Button(frame, text="(5,'Bam')",command=ba5)
ba5.grid(row=11,column=6)
ba6 = tk.Button(frame, text="(6,'Bam')",command=ba6)
ba6.grid(row=11,column=7)
ba7 = tk.Button(frame, text="(7,'Bam')",command=ba7)
ba7.grid(row=11,column=8)
ba8 = tk.Button(frame, text="(8,'Bam')",command=ba8)
ba8.grid(row=11,column=9)
ba9 = tk.Button(frame, text="(9,'Bam')",command=ba9)
ba9.grid(row=11,column=10)
# crack
cr0 = tk.Button(frame, text="RED",command=cr0)
cr0.grid(row=12,column=1)
cr1 = tk.Button(frame, text="(1,'Crack')",command=cr1)
cr1.grid(row=12,column=2)
cr2 = tk.Button(frame, text="(2,'Crack')",command=cr2)
cr2.grid(row=12,column=3)
cr3 = tk.Button(frame, text="(3,'Crack')",command=cr3)
cr3.grid(row=12,column=4)
cr4 = tk.Button(frame, text="(4,'Crack')",command=cr4)
cr4.grid(row=12,column=5)
cr5 = tk.Button(frame, text="(5,'Crack')",command=cr5)
cr5.grid(row=12,column=6)
cr6 = tk.Button(frame, text="(6,'Crack')",command=cr6)
cr6.grid(row=12,column=7)
cr7 = tk.Button(frame, text="(7,'Crack')",command=cr7)
cr7.grid(row=12,column=8)
cr8 = tk.Button(frame, text="(8,'Crack')",command=cr8)
cr8.grid(row=12,column=9)
cr9 = tk.Button(frame, text="(9,'Crack')",command=cr9)
cr9.grid(row=12,column=10)
# dot
do0 = tk.Button(frame, text="SOAP",command=do0)
do0.grid(row=13,column=1)
do1 = tk.Button(frame, text="(1,'Dot')",command=do1)
do1.grid(row=13,column=2)
do2 = tk.Button(frame, text="(2,'Dot')",command=do2)
do2.grid(row=13,column=3)
do3 = tk.Button(frame, text="(3,'Dot')",command=do3)
do3.grid(row=13,column=4)
do4 = tk.Button(frame, text="(4,'Dot')",command=do4)
do4.grid(row=13,column=5)
do5 = tk.Button(frame, text="(5,'Dot')",command=do5)
do5.grid(row=13,column=6)
do6 = tk.Button(frame, text="(6,'Dot')",command=do6)
do6.grid(row=13,column=7)
do7 = tk.Button(frame, text="(7,'Dot')",command=do7)
do7.grid(row=13,column=8)
do8 = tk.Button(frame, text="(8,'Dot')",command=do8)
do8.grid(row=13,column=9)
do9 = tk.Button(frame, text="(9,'Dot')",command=do9)
do9.grid(row=13,column=10)
# winds, joker, and flower
no = tk.Button(frame, text="(North,'x')",command=no)
no.grid(row=14,column=1)
ea = tk.Button(frame, text="('East','x')",command=ea)
ea.grid(row=14,column=2)
we = tk.Button(frame, text="('West','x')",command=we)
we.grid(row=14,column=3)
so = tk.Button(frame, text="('South','x')",command=so)
so.grid(row=14,column=4)
jo = tk.Button(frame, text="('Joker','x')",command=jo)
jo.grid(row=14,column=5)
fl = tk.Button(frame, text="('Flower','x')",command=fl)
fl.grid(row=14,column=6)

# skip space 3
skip_space_3 = tk.Label(frame, text="")
skip_space_3.grid(row=15, column = 1, columnspan = 10)

# discard tiles
discard_tiles = tk.Label(frame, text="Remove Tiles from LIVE DECK")
discard_tiles.grid(row=16, column = 1, columnspan = 9)
reset_deck = tk.Button(frame, text="RESET DECK",command=reset_deck)
reset_deck.grid(row=16,column=10)
# bam
b0 = tk.Button(frame, text="GREEN",command=b0)
b0.grid(row=17,column=1)
b1 = tk.Button(frame, text="(1,'Bam')",command=b1)
b1.grid(row=17,column=2)
b2 = tk.Button(frame, text="(2,'Bam')",command=b2)
b2.grid(row=17,column=3)
b3 = tk.Button(frame, text="(3,'Bam')",command=b3)
b3.grid(row=17,column=4)
b4 = tk.Button(frame, text="(4,'Bam')",command=b4)
b4.grid(row=17,column=5)
b5 = tk.Button(frame, text="(5,'Bam')",command=b5)
b5.grid(row=17,column=6)
b6 = tk.Button(frame, text="(6,'Bam')",command=b6)
b6.grid(row=17,column=7)
b7 = tk.Button(frame, text="(7,'Bam')",command=b7)
b7.grid(row=17,column=8)
b8 = tk.Button(frame, text="(8,'Bam')",command=b8)
b8.grid(row=17,column=9)
b9 = tk.Button(frame, text="(9,'Bam')",command=b9)
b9.grid(row=17,column=10)
# crack
c0 = tk.Button(frame, text="RED",command=c0)
c0.grid(row=18,column=1)
c1 = tk.Button(frame, text="(1,'Crack')",command=c1)
c1.grid(row=18,column=2)
c2 = tk.Button(frame, text="(2,'Crack')",command=c2)
c2.grid(row=18,column=3)
c3 = tk.Button(frame, text="(3,'Crack')",command=c3)
c3.grid(row=18,column=4)
c4 = tk.Button(frame, text="(4,'Crack')",command=c4)
c4.grid(row=18,column=5)
c5 = tk.Button(frame, text="(5,'Crack')",command=c5)
c5.grid(row=18,column=6)
c6 = tk.Button(frame, text="(6,'Crack')",command=c6)
c6.grid(row=18,column=7)
c7 = tk.Button(frame, text="(7,'Crack')",command=c7)
c7.grid(row=18,column=8)
c8 = tk.Button(frame, text="(8,'Crack')",command=c8)
c8.grid(row=18,column=9)
c9 = tk.Button(frame, text="(9,'Crack')",command=c9)
c9.grid(row=18,column=10)
# dot
d0 = tk.Button(frame, text="SOAP",command=d0)
d0.grid(row=19,column=1)
d1 = tk.Button(frame, text="(1,'Dot')",command=d1)
d1.grid(row=19,column=2)
d2 = tk.Button(frame, text="(2,'Dot')",command=d2)
d2.grid(row=19,column=3)
d3 = tk.Button(frame, text="(3,'Dot')",command=d3)
d3.grid(row=19,column=4)
d4 = tk.Button(frame, text="(4,'Dot')",command=d4)
d4.grid(row=19,column=5)
d5 = tk.Button(frame, text="(5,'Dot')",command=d5)
d5.grid(row=19,column=6)
d6 = tk.Button(frame, text="(6,'Dot')",command=d6)
d6.grid(row=19,column=7)
d7 = tk.Button(frame, text="(7,'Dot')",command=d7)
d7.grid(row=19,column=8)
d8 = tk.Button(frame, text="(8,'Dot')",command=d8)
d8.grid(row=19,column=9)
d9 = tk.Button(frame, text="(9,'Dot')",command=d9)
d9.grid(row=19,column=10)
# winds, joker, and flower
n = tk.Button(frame, text="(North,'x')",command=n)
n.grid(row=20,column=1)
e = tk.Button(frame, text="('East','x')",command=e)
e.grid(row=20,column=2)
w = tk.Button(frame, text="('West','x')",command=w)
w.grid(row=20,column=3)
s = tk.Button(frame, text="('South','x')",command=s)
s.grid(row=20,column=4)
j = tk.Button(frame, text="('Joker','x')",command=j)
j.grid(row=20,column=5)
f = tk.Button(frame, text="('Flower','x')",command=f)
f.grid(row=20,column=6)

# tile values
tile_values_label = tk.Label(frame, text="TILE VALUES   Hands Considered: ")
tile_values_label.grid(row=1, column = 12, columnspan = 3, sticky = 'e')
hands_considered_text = str(optimize_values(run_hand(df_full, your_hand, alive), your_hand)[0])
hands_considered = tk.Label(frame, text = hands_considered_text)
hands_considered.grid(row = 1, column = 15)
tile_values_text = str(optimize_values(run_hand(df_full, your_hand, alive), your_hand)[1])
tile_values_2 = tk.Label(frame, text = tile_values_text)
tile_values_2.grid(row = 2, column = 12, columnspan = 4, rowspan = 18)

# skip space 4
skip_space_4 = tk.Label(frame, text="")
skip_space_4.grid(row=21, column = 1, columnspan = 15)

# top 3 hands
tile_values_label = tk.Label(frame, text="TOP 3 HANDS")
tile_values_label.grid(row=22, column = 1, columnspan = 15)
top_3_hands_1_text = str(df_full.iloc[0:3,2])
top_3_hands_1 = tk.Label(frame, text = top_3_hands_1_text)
top_3_hands_1.grid(row=23, column = 1, columnspan = 8)
top_3_hands_2_text = str(df_full.iloc[0:3,[4,3,5,6,9,8]])
top_3_hands_2 = tk.Label(frame, text = top_3_hands_2_text)
top_3_hands_2.grid(row=23, column = 9, columnspan = 6)

# alive
alive_label = tk.Label(frame, text="LIVE DECK")
alive_label.grid(row=1, column = 17, sticky = 'e')
alive_df = pd.DataFrame({'TILE':list(alive.keys()),'REMAINING':list(alive.values())})
alive_keys_text = str(alive_df.iloc[:,0])
alive_keys = tk.Label(frame, text = alive_keys_text)
alive_keys.grid(row=2, column = 16, rowspan = 36)
alive_values_text =str(alive_df.iloc[:,1])
alive_values = tk.Label(frame, text = alive_values_text)
alive_values.grid(row=2, column = 17, rowspan = 36)

root.mainloop()

# %%
# for trading, input your_hand and reset deck after each hand

# for game play, add and remove from your_hand with each tile and kill each 
# tile discarded by other players by removing them from the live deck

# %%
your_hand
# Out:
# []
